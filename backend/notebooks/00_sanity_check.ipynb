# %%
import sys
import os

# Add backend path
sys.path.append(os.path.abspath(".."))

# Add llm_config path
sys.path.append(os.path.abspath("../llm_config"))

from llm_client import get_client
from config import MODEL

client = get_client()

response = client.chat.completions.create(
model=MODEL,
messages = [ { "role": "user", "content": [
{"type": "text", "text": "Whats in this image?"},
{"type": "image_url", "image_url": { "url": "https://nam04.safelinks.protection.outlook.com/?url=https%3A%2F%2Fhuggingface.co%2Fdatasets%2Fhuggingface%2Fdocumentation-images%2Fresolve%2Fmain%2Ftransformers%2Frabbit.png&data=05%7C02%7Cmnipu2%40groute.uic.edu%7C8d07058feae64dd3063a08de7499dfab%7Ce202cd477a564baa99e3e3b71a7c77dd%7C0%7C0%7C639076401445006736%7CUnknown%7CTWFpbGZsb3d8eyJFbXB0eU1hcGkiOnRydWUsIlYiOiIwLjAuMDAwMCIsIlAiOiJXaW4zMiIsIkFOIjoiTWFpbCIsIldUIjoyfQ%3D%3D%7C0%7C%7C%7C&sdata=u62kZ5f72fBdB51MFoAreJLoVX3IZ7DtJ7a1c1VrFcU%3D&reserved=0" } }
]
}])

print(response.choices[0].message.content)


resp = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "user", "content": "Say hello in one sentence."}
    ]
)

resp.choices[0].message.content

print(resp.choices[0].message.content)
# Out:
# The image depicts a rabbit dressed in a spacesuit, standing on a rocky, orange-hued terrain that resembles the surface of Mars. The rabbit has large ears and is wearing a white spacesuit with blue and brown accents, featuring a red button on the chest. The background includes a large, curved rock formation and a bright light source, possibly the sun, casting an orange glow over the scene.
#
# **Key Elements:**
#
# * **Rabbit in Spacesuit:** The central figure is a rabbit with large ears, dressed in a detailed spacesuit.
# * **Terrain:** The ground appears to be Martian or Mars-like, with orange-red rocks and soil.
# * **Spacesuit Details:** The suit is white with blue and brown accents and includes a red button on the chest.
# * **Background:** A large, curved rock formation is visible on the left, and a bright light source (possibly the sun) is on the right, casting an orange glow.
#
# **Overall Impression:**
# The image suggests a futuristic or sci-fi scenario where a rabbit is exploring another planet, likely Mars, given the terrain. The detailed spacesuit and the alien landscape create a vivid and imaginative scene.
# Hello!
