# %%
import sys
import os

# Add backend path
sys.path.append(os.path.abspath(".."))

# Add llm_config path
sys.path.append(os.path.abspath("../llm_config"))

from llm_client import get_client
from config import MODEL

client = get_client()

response = client.chat.completions.create(
model=MODEL,
messages = [ { "role": "user", "content": [
{"type": "text", "text": "Whats in this image?"},
{"type": "image_url", "image_url": { "url": "https://nam04.safelinks.protection.outlook.com/?url=https%3A%2F%2Fhuggingface.co%2Fdatasets%2Fhuggingface%2Fdocumentation-images%2Fresolve%2Fmain%2Ftransformers%2Frabbit.png&data=05%7C02%7Cmnipu2%40groute.uic.edu%7C8d07058feae64dd3063a08de7499dfab%7Ce202cd477a564baa99e3e3b71a7c77dd%7C0%7C0%7C639076401445006736%7CUnknown%7CTWFpbGZsb3d8eyJFbXB0eU1hcGkiOnRydWUsIlYiOiIwLjAuMDAwMCIsIlAiOiJXaW4zMiIsIkFOIjoiTWFpbCIsIldUIjoyfQ%3D%3D%7C0%7C%7C%7C&sdata=u62kZ5f72fBdB51MFoAreJLoVX3IZ7DtJ7a1c1VrFcU%3D&reserved=0" } }
]
}])

print(response.choices[0].message.content)


resp = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "user", "content": "Say hello in one sentence."}
    ]
)

resp.choices[0].message.content

print(resp.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-ba0d65f3c4aa4d24b161b41ebf3dbde7', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The image depicts an anthropomorphic rabbit dressed in a space suit standing on a rocky, orange-hued planet. \n\nThe rabbit has brown fur and large ears, and it is wearing a white and blue space suit with a red button on the chest. The background features a rocky, orange landscape with a large rock formation on the left side of the image and a bright light source on the right side. The overall atmosphere suggests that the rabbit is on a mission to explore the planet.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1772050296, model='llama4-nim', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=97, prompt_tokens=742, total_tokens=839, completion_tokens_details=None, prompt_tokens_details=None))
